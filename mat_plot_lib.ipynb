# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = [1, 2, 3, 4]
y = [3, 9, 7, 4]
plt.bar(x,y);

# %%
plt.plot(x,y);

# %%
plt.scatter(x,y);

# %%
plt.pie(x, y);  
#why this is like this?!!

# %%
plt.hexbin(x,y);
#why this is like this

# %%
plt.bar(x, y, color='green');
plt.title('this is title of chart')
plt.xlabel('x lable')
plt.ylabel(' y lable')
# Out:
# Text(0, 0.5, ' y lable')

# %% [markdown]
# ## How to show values or labels on top of bar

# %%
barplot = plt.bar(x, y, color='red');
for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0,
            yval, int(yval), va='bottom')
    
plt.title('title')
plt.xlabel('xlabel')
plt.ylabel('ylabel');

# %%
x1 = [2, 1, 3, 5]
print(y)
plt.barh(x1,y)
# Out:
# [3, 9, 7, 4]
# <BarContainer object of 4 artists>

# %%
# i am trying to do same for horizental bar

hbarplot = plt.barh(x, y, color='red');
for bar in hbarplot:
    print(bar)
    xval = bar.get_width()
    plt.text(bar.get_x()+ bar.get_width()/2.0 ,xval,
             int(xval))
    
plt.title('title')
plt.xlabel('xlabel')
plt.ylabel('ylabel');
# Out:
# Rectangle(xy=(0, 0.6), width=3, height=0.8, angle=0)
# Rectangle(xy=(0, 1.6), width=9, height=0.8, angle=0)
# Rectangle(xy=(0, 2.6), width=7, height=0.8, angle=0)
# Rectangle(xy=(0, 3.6), width=4, height=0.8, angle=0)

# %% [markdown]
# ## sort bars

# %%
#this part is not working good

x1 = [2, 1, 3, 5]
# x = [1, 2, 3, 4]
# y = [3, 9, 7, 4]
x2,y = zip(*sorted(zip(x1,y)))

print(x1)
print(x2)
print(y)
# Out:
# [2, 1, 3, 5]
# (1, 2, 3, 5)
# (9, 3, 7, 4)

# %%
plt.bar(x1,y,color='green');

# %%
#for sorting i follow the notes:
X = ['A', 'B', 'C', 'D', 'E']
Y = [5, 7, 3, 8, 4]
plt.barh(X, Y);

# %% [markdown]
# To arrange bars in order based on values not alphabetically, we need to combine both the lists and then sort them based on value of list y. zip( ) function is used to combine items of lists x and y. sorted( )sort them based on y. Then we split and store it in x and y lists.

# %%
#Z = zip(X, Y)
#print(tuple(Z))
Y, X = zip(*sorted(zip(Y, X)))
# print(X)
# print(Y)
# print(X1)
# print(Y1)
plt.barh(X, Y);

# %%
Z1 = zip(X, Y)
Z2 = zip(Y, X)
print(tuple(Z1))
print(tuple(Z2))
print(tuple(zip(*sorted(zip(Y,X)))))
#the star remove extra brakets
# Out:
# (('C', 3), ('E', 4), ('A', 5), ('B', 7), ('D', 8))
# ((3, 'C'), (4, 'E'), (5, 'A'), (7, 'B'), (8, 'D'))
# ((3, 4, 5, 7, 8), ('C', 'E', 'A', 'B', 'D'))

# %%
Y, X = zip(*sorted(zip(Y, X)))
plt.barh(X, Y)
plt.gca().invert_yaxis()
##Reverse order of bars

# %% [markdown]
# ## List of Professional Themes / Styles for Graphs

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
Y, X = zip(*sorted(zip(Y, X)))
plt.barh(X, Y, color='yellow')
plt.gca().invert_yaxis()
plt.style.use('seaborn-poster')
# plt.style.use('classic')

# %% [markdown]
# ## Line Graph

# %%
import pandas as pd

df = pd.DataFrame({"Year" : [2014, 2015, 2016, 2017, 2018], 
                  "Sales" : [2000, 3000, 4000, 3500, 6000]})
display(df)
# Out:
#    Year  Sales
# 0  2014   2000
# 1  2015   3000
# 2  2016   4000
# 3  2017   3500
# 4  2018   6000

# %%
plt.plot(df["Year"], df['Sales'])
plt.title('sample line plot')
plt.xlabel('Year')
plt.ylabel('Sale')
plt.style.use('classic')

# %% [markdown]
#  Pandas can make graphs by calling plot directly from the data frame. Plot can be called by defining plot type in kind= option. Syntax of Plot in Pandas.
#
#  By making use of style= option, you can include marker with customization in color and style.
#
#  You can also use these styles ro, ro--, r+, rD-.. They refer to cirles, dash lines, dash-dotted lines. You can mention any color ('g' for green, 'b' for blue, 'k' for black etc.)

# %%
ax = df.plot(x='Year', y='Sales', kind='line', title='Sample Line Plot',
            legend=False, style='go--')
ax.set(ylabel='Sales', xlabel = 'Year', xticks =df["Year"])
# ax.set_xlim(2013,2019);
# Out:
# [Text(0, 0.5, 'Sales'),
# ...
#  Text(0.5, 0, 'Year')]

# %% [markdown]
# ```.set``` method is used to add x and y axis labels, limits and ticks. It can also be written like the code below:
#
# ```python
#    ax.set_ylabel('Sales')
#    ax.set_xlabel('Year')
#    ax.set_xticks(df["Year"])
# ```

# %% [markdown]
# Syntax of ```ax.set``` family functions is equivalent to plt. styling functions. See comparison of some of them -
#
# ```python
# ax.set_ylabel() plt.ylabel()
# ax.set_xlabel() plt.xlabel()
# ax.set_xticks() plt.xticks()
# ```
# ```legend=False``` tells pandas to turnoff legend

# %% [markdown]
# ## Add Multiple Lines in Line Graph Pandas Way

# %%
product = pd.DataFrame({"Year" : [2014,2015,2016,2017,2018], 
                  "ProdASales" : [2000, 3000, 4000, 3500, 6000],
                  "ProdBSales" : [3000, 4000, 3500, 3500, 5500]})

# %%
# Multi line plot
ax = product.plot("Year", "ProdASales", kind="line", label = 'Product A Sales')
product.plot("Year", "ProdBSales", ax= ax , kind="line",
             label = 'Product B Sales', title= 'MultiLine Plot') #ax : axes object

# Set axes
ax.set(ylabel='Sales', xlabel = 'Year', xticks =df["Year"]);

# %%
# How to show years with same interval as it is defined in column
ax = df.plot(x="Year", y="Sales", kind="line", title ="Simple Line Plot", legend=False)
ax.set(ylabel='Sales', xlabel = 'Year', xticks =df["Year"]);

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# ```kind = 'scatter'``` is used for creating scatter diagram.

# %%
ax = product.plot("Year", "ProdASales", kind='scatter', color = 'red', title = 'Year by ProductA Sales')
ax.set(ylabel='ProductA Sales', xlabel = 'Year', xticks =df["Year"]);

# %% [markdown]
# ## Pie Chart

# %%
share = [20, 12, 11, 4, 3]
companies = ['Google', 'Facebook', 'Apple', 'Microsoft', 'IBM', ]
comp = pd.DataFrame({"share" : share, "companies" : companies})


ax = comp.plot(y="share", kind="pie", labels = comp["companies"], autopct = '%1.0f%%',
               legend=False, title='Market Share')

# Hide y-axis label
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %% [markdown]
# ## Customize Pie Chart:
#
# The default startangle is 0. By making ```startangle = 90``` , everything will be rotated counter-clockwise by 90 degrees. By using ```explode = option```, you can explode specific categories. In the following program, we are exploding first three categories.

# %%
ax = comp.plot(y="share", kind="pie", labels = comp["companies"], 
               startangle = 90, shadow = True, 
               explode = (0.1, 0.1, 0.1, 0, 0), 
               autopct = '%1.0f%%', legend=False, title='Market Share')
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %% [markdown]
# ## Histogram

# %%
# Creating random data
import numpy as np
np.random.seed(1)
mydf = pd.DataFrame({"Age" : np.random.randint(low=20, high=100, size=50)})

# Histogram
ax = mydf.plot(bins= 5, kind="hist", rwidth = 0.7, title = 'Distribution - Marks',
               legend=False)
ax.set(xlabel="Bins")
# Out:
# [Text(0.5, 0, 'Bins')]

# %% [markdown]
# ```bins``` represents the number of intervals you want to show on x axis. ```rwidth``` show the relative width of the bars as a fraction of the bin width

# %%
ax = mydf.plot(bins= 7, kind="hist", rwidth = 0.8 , title = 'Distribution - Marks',
               legend=False)
ax.set(xlabel="Bins")
# Out:
# [Text(0.5, 0, 'Bins')]

# %% [markdown]
# ## How to add multiple sub-plots
#
# With the use of matplotlib library, we can generate multiple sub-plots in the same graph or figure. Matplotlib provides two interfaces to do this task - ```plt.subplots( )``` and ```plt.figure()```. Logic is similar in both the ways - we will have a figure and we'll add multiple axes (sub-plots) on the figure one by one.

# %%
labels = ['Delhi', 'Mumbai', 'Bangalore', 'Chennai']
x1 = [45, 30, 15, 10]
x2 = [25, 20, 25, 50]

finaldf = pd.DataFrame({"2017_Score":x1, "2018_Score" : x2, "Cities" : labels})
display(finaldf)
# Out:
#    2017_Score  2018_Score     Cities
# 0          45          25      Delhi
# 1          30          20     Mumbai
# 2          15          25  Bangalore
# 3          10          50    Chennai

# %% [markdown]
# ```.add_subplot()``` or ```.subplots()``` follows the syntax rule
#
# ```subplot(number of rows, number of columns, plot number)```
# ```python
# .add_subplot(121) means 1 row, 2 columns and 1st plot
# .add_subplot(122) means 1 row, 2 columns and 2nd plot
# ```
# Similarly, ```.subplots(1, 2)``` means 1 row and 2 columns

# %% [markdown]
# ## mathod I

# %%
fig = plt.figure()

ax1 = fig.add_subplot(121)
ax = finaldf.plot(x="Cities",  y="2017_Score", ax=ax1, 
                  kind="barh", legend = False, title = "2017 Score")
ax.invert_yaxis()

ax2 = fig.add_subplot(122)
ax = finaldf.plot(x="Cities",  y="2018_Score", ax=ax2, 
                  kind="barh", legend = False, title = "2018 Score")
ax.invert_yaxis()
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %% [markdown]
# ## Method II

# %%
fig, (ax0, ax01) = plt.subplots(1, 2)

ax = finaldf.plot(x="Cities",  y="2017_Score", ax=ax0, kind="barh", legend = False, title = "2017 Score")
ax.invert_yaxis()

ax = finaldf.plot(x="Cities",  y="2018_Score", ax=ax01, kind="barh", legend = False, title = "2018 Score")
ax.invert_yaxis()
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %% [markdown]
# These 3 lines of code return blank (empty) 2 sub-plots. 121 refers to left hand side plot and 122 refers to right hand side plot. With the use of ```ax= ```object we use axes and control positioning of sub-plots.
# ```python
# fig = plt.figure()
# fig.add_subplot(121)
# fig.add_subplot(122)
# ```

# %% [markdown]
# ## Vertically sub-plot
# Here we are using 211 and 222 in ```subplot( )``` function. 211 means 2 rows, 1 column and 1st plot.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax = finaldf.plot(x='Cities', y='2017_Score', ax=ax1, kind='barh', 
                  legend=False, title='2017 va 2018 Score')
ax.invert_yaxis()
plt.xticks(range(0,60,10))
ax.set(ylabel='')

ax2 = fig.add_subplot(212)
ax = finaldf.plot(x="Cities",  y="2018_Score", ax=ax2, kind="barh", legend = False)
ax.invert_yaxis()
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %% [markdown]
# ## How to save plot

# %%
# !pwd
# Out:
# /cygdrive/d/Data_visualization

# %%
x = ['A','B','C', 'D']
y = [1,2,3,4]
fig = plt.figure()
plt.bar(x, y)
fig.savefig('/Users/mehdi/python/firstimg.png')
plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-e4ac78854134> in <module>
#       3 fig = plt.figure()
#       4 plt.bar(x, y)
# ----> 5 fig.savefig('/Users/mehdi/python/firstimg.png')
#       6 plt.close(fig)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2087                     orientation=orientation,
#    2088                     bbox_inches_restore=_bbox_inches_restore,
# -> 2089                     **kwargs)
# ...

# %% [markdown]
# ## How to set different limits in axis
# Suppose you have a bar graph and you want to set limits in x and y axis manually. ```plt.subplot()``` returns axes. In ```set_ylim( )```, you can assign limits which is smallest and largest value of y axis. Similarly you can set limit in x-axis.

# %%
x = [1, 2, 3, 4]
y = [100,119,800,900]
plt.bar(x, y)
ax = plt.subplot()
ax.set_ylim(0,1100)
ax.set_xlim(0,4.5)
# Out:
# C:\Users\hanif\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.
# (0, 4.5)

# %% [markdown]
# ## How to show multiple entries in legend
# ```python
# plt.legend(["First","Second"])
# ```

# %% [markdown]
# ## Exercise

# %% [markdown]
# Get your hands dirty with this exercise. Prepare the graph shown below using dataframe ```finaldf```. Give attention to each part of the graph and try to replicate it. Post your solution in the comment box below.

# %%
ax = finaldf.plot.barh(x='Cities', rot=0)
plt.title("Cost of Living Index", fontsize=18, fontweight='bold')
plt.xlabel('Score', fontsize=16)
plt.ylabel("Cities", fontsize=16)
ax.set_xlim(0,55)
ax.invert_yaxis()

# %%
ax=finaldf.plot(x='Cities',kind='barh')
plt.xlabel('score',color='black')
plt.ylabel('Cities',color='black')
ax.invert_yaxis()
legend = ax.legend([2017,2018],frameon=True)

plt.title('Cost of Living Index',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Cost of Living Index')

# %% [markdown]
# ## example

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["225 g flour",
          "90 g sugar",
          "1 egg",
          "60 g butter",
          "100 ml milk",
          "1/2 package of yeast"]

data = [225, 90, 50, 60, 100, 5]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

# %% [markdown]
# ## refrence:
#
# https://www.listendata.com/2019/06/matplotlib-tutorial-learn-plot-python.html?showComment=1562008669030#c3859554775126611577
